# %% [markdown]
# # Assignment 1
# You should submit the **UniversityNumber.ipynb** file and your final prediction file **UniversityNumber.test.out** to Moodle. Make sure your code does not use your local files and that the results are reproducible. Before submitting, please **run your notebook and keep all running logs** so that we can check.

# %% [markdown]
# ## 1 $n$-gram Language Model
# **Q1**: Expand the above definition of $ p(\vec{w})$ using naive estimates of the parameters, such as $  p(w_4 \mid w_2, w_3) \stackrel{\tiny{\mbox{def}}}{=}  \frac{C(w_2~w_3~w_4)}{C(w_2~w_3)} $ where \( C(w_2 w_3 w_4) \) denotes the count of times the trigram $ w_2 w_3 w_4 $ was observed in a training corpus.

# %% [markdown]
# **Write your answer:**
#
# \# todo
#
# $  p(\vec{w}) \stackrel{\tiny{\mbox{def}}}{=}
# \frac{C(w_1)}{|\vec{w}|} \cdot
# \frac{C(w_1~w_2)}{C(w_1)} \cdot
# \frac{C(w_1~w_2~w_3)}{C(w_1~w_2)} \cdot
# \frac{C(w_2~w_3~w_4)}{C(w_2~w_3)} \\ \cdots
# \frac{C(w_n-2~w_n-1~w_n)}{C(w_n-1~w_n)}  $

# %% [markdown]
# **Q2**: One could also define a kind of reversed trigram language model $p_{reversed}$ that instead assumed the words were generated in reverse order (from right to left):
# \begin{align} p_{reversed}(\vec{w}) \stackrel{\tiny{\mbox{def}}}{=}&p(w_n) \cdot p(w_{n-1} \mid w_n) \cdot p(w_{n-2} \mid w_{n-1} w_n) \cdot p(w_{n-3} \mid w_{n-2} w_{n-1}) \\ &\cdots p(w_2 \mid w_3 w_4) \cdot p(w_1 \mid w_2 w_3) \end{align}
# By manipulating the notation, show that the two models are identical, i.e., $ p(\vec{w}) = p_{reversed}(\vec{w}) $ for any $ \vec{w} $ provided that both models use MLE parameters estimated from the same training data (see Q1 above).

# %% [markdown]
# **Write your answer:**
#
# \# todo
#
# $  p(\vec{w}) \stackrel{\tiny{\mbox{def}}}{=}
# \frac{C(w_1)}{|\vec{w}|} \cdot
# \frac{C(w_1~w_2)}{C(w_1)} \cdot
# \frac{C(w_1~w_2~w_3)}{C(w_1~w_2)} \cdot
# \frac{C(w_2~w_3~w_4)}{C(w_2~w_3)} \\ \cdots
# \frac{C(w_{n-2}~w_{n-1}~w_{n})}{C(w_{n-2}~w_{n-1})}
# \\ {=}
# \frac{C(w_1)}{C(w_1)} \cdot
# \frac{C(w_1~w_2)}{C(w_1~w_2)} \cdot
# \frac{C(w_1~w_2~w_3)}{C(w_2~w_3)} \cdot
# \frac{C(w_2~w_3~w_4)}{C(w_3~w_4)} \\ \cdots
# \frac{C(w_{n-3}~w_{n-2}~w_{n-1})}{C(w_{n-2}~w_{n-1})} ⋅
# \frac{C(w_{n-2}~w_{n-1}~w_n)}{1} ⋅
# \frac{1}{|\vec{w}|}
# \\ {=}
# {1} \cdot
# \frac{C(w_1~w_2)}{C(w_1~w_2)} \cdot
# \frac{C(w_1~w_2~w_3)}{C(w_2~w_3)} \cdot
# \frac{C(w_2~w_3~w_4)}{C(w_3~w_4)} \\ \cdots
# \frac{C(w_{n-3}~w_{n-2}~w_{n-1})}{C(w_{n-2}~w_{n-1})} ⋅
# \frac{C(w_{n-2}~w_{n-1}~w_n)}{1} ⋅
# \frac{1}{C(w_n)}
# \\ {=}
# \frac{C(w_1~w_2~w_3)}{C(w_2~w_3)} \cdot
# \frac{C(w_2~w_3~w_4)}{C(w_3~w_4)} \\ \cdots
# \frac{C(w_{n-3}~w_{n-2}~w_{n-1})}{C(w_{n-2}~w_{n-1})} ⋅
# \frac{C(w_{n-2}~w_{n-1}~w_n)}{C(w_{n-1}~w_n)} ⋅
# \frac{C(w_{n-1}~w_n)}{C(w_n)}⋅
# {1}
# \\ {=}
# \frac{C(w_n)}{|\vec{w}|} \cdot
# \frac{C(w_n~w_{n-1})}{C(w_n)} \cdot
# \frac{C(w_n~w_{n-1}~w_{n-2})}{C(w_n~w_{n-1})} \cdot
# \frac{C(w_{n-1}~w_{n-2}~w_{n-3})}{C(w_{n-1}~w_{n-2})} \\ \cdots
# \frac{C(w_3~w_2~w_1)}{C(w_3~w_2)}
# \\{=}
# p_{reversed}(\vec{w})   $

# %% [markdown]
# ## 2 $N$-gram Language Model Implementation

# %%
# !wget -O train.txt https://raw.githubusercontent.com/qtli/COMP7607-Fall2023/master/assignments/A1/data/lm/train.txt
# !wget -O dev.txt https://raw.githubusercontent.com/qtli/COMP7607-Fall2023/master/assignments/A1/data/lm/dev.txt
# !wget -O test.txt https://raw.githubusercontent.com/qtli/COMP7607-Fall2023/master/assignments/A1/data/lm/test.txt
# Out:
# --2023-10-21 01:57:50--  https://raw.githubusercontent.com/qtli/COMP7607-Fall2023/master/assignments/A1/data/lm/train.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6640478 (6.3M) [text/plain]
# Saving to: ‘train.txt’
#
# train.txt           100%[===================>]   6.33M  --.-KB/s    in 0.07s
#
# 2023-10-21 01:57:51 (94.2 MB/s) - ‘train.txt’ saved [6640478/6640478]
#
# --2023-10-21 01:57:51--  https://raw.githubusercontent.com/qtli/COMP7607-Fall2023/master/assignments/A1/data/lm/dev.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 872910 (852K) [text/plain]
# Saving to: ‘dev.txt’
#
# dev.txt             100%[===================>] 852.45K  --.-KB/s    in 0.04s
#
# 2023-10-21 01:57:51 (20.5 MB/s) - ‘dev.txt’ saved [872910/872910]
#
# --2023-10-21 01:57:51--  https://raw.githubusercontent.com/qtli/COMP7607-Fall2023/master/assignments/A1/data/lm/test.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 869318 (849K) [text/plain]
# Saving to: ‘test.txt’
#
# test.txt            100%[===================>] 848.94K  --.-KB/s    in 0.04s
#
# 2023-10-21 01:57:51 (22.8 MB/s) - ‘test.txt’ saved [869318/869318]

# %% [markdown]
# ### 2.1 Building vocabulary

# %% [markdown]
# **Code**
#
# \# todo

# %%
import numpy as np
from scipy.stats import gmean

import nltk
nltk.download("stopwords")
nltk.download('punkt')
nltk.download("stopwords")

from nltk import lm
from nltk.lm import preprocessing
import io
from nltk.corpus import PlaintextCorpusReader
from nltk.corpus import stopwords

from nltk.util import ngrams
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
train = PlaintextCorpusReader("./","train.txt")
sents = train.sents()
# words = train.words()


# Add start-of-sentence tokens <s> and end-of-sentence </s> tokens.
uni_train,_ = preprocessing.padded_everygram_pipeline(1,sents)
bi_train,_  = preprocessing.padded_everygram_pipeline(2,sents)
tri_train,v = preprocessing.padded_everygram_pipeline(3,sents)

# Convert tokens that occur less than three times in the training data into a special unknown token <UNK>.
vocab = lm.Vocabulary(v,unk_cutoff=3)

# Print the vocabulary size.
print("Vocabulary size is:", len(vocab))

# for sent in train_text:
#     print(list(sent))
# Out:
# Vocabulary size is: 16948

# %% [markdown]
# **Discussion**
#
# \# todo
#
# The size of vocabulary is 16948.
# There are 1 parameter in unigram model, 2 in bigram model, 3 in trigram model.

# %% [markdown]
# ### 2.2 $N$-gram Language Modeling

# %% [markdown]
# **Code**
#
# \# todo

# %%
uni_model = lm.MLE(1)
bi_model  = lm.MLE(2)
tri_model = lm.MLE(3)

uni_model.fit(uni_train,vocab)
bi_model.fit(bi_train,vocab)
# tri_model.fit(tri_train,vocab)

# len(bi_model.vocab)
# bi_model.vocab.lookup("</s>")

# %%
train = PlaintextCorpusReader("./","train.txt")
sents = train.sents()

uni_train,_ = preprocessing.padded_everygram_pipeline(1,sents)
bi_train,_  = preprocessing.padded_everygram_pipeline(2,sents)
# tri_train,_ = preprocessing.padded_everygram_pipeline(3,sents)

ppl = []
for sent in uni_train:
    ppl.append(uni_model.perplexity(list(sent)))
ppl_mean = gmean(ppl)
print("Perplexity of Unigram Model over train dataset:",ppl_mean)

ppl = []
for sent in bi_train:
    ppl.append(bi_model.perplexity(list(sent)))
ppl_mean = gmean(ppl)
print("Perplexity of Bigram Model over train dataset:",ppl_mean)
# Out:
# Perplexity of Unigram Model over train dataset: 977.7254663002035
# Perplexity of Bigram Model over train dataset: 216.62822602581886

# %%
test  = PlaintextCorpusReader("./","dev.txt")
sents = test.sents()

uni_dev,_ = preprocessing.padded_everygram_pipeline(1,sents)
bi_dev,_  = preprocessing.padded_everygram_pipeline(2,sents)
tri_dev,_ = preprocessing.padded_everygram_pipeline(3,sents)

ppl = []
for sent in uni_dev:
    ppl.append(uni_model.perplexity(list(sent)))
ppl_mean = gmean(ppl)
print("Perplexity of Unigram Model over dev dataset:",ppl_mean)

ppl = []
for sent in bi_dev:
    ppl.append(bi_model.perplexity(list(sent)))
# ppl_mean = np.mean(ppl)
ppl_mean = gmean(ppl)
print("Perplexity of Bigram Model over dev dataset:",ppl_mean)
# Out:
# Perplexity of Unigram Model over dev dataset: 945.1187134309084
# Perplexity of Bigram Model over dev dataset: inf

# %% [markdown]
# **Discussion**
#
# \# todo
#
# As shown above, the perplexity of Unigram Model over train dataset and dev dataset is about 978 and 945 respectively.
#
#
# The Perplexty of Bigram Model over train dataset and dev dataset is about 217 and infinite number respectively.

# %% [markdown]
# ### 2.3 Smoothing

# %% [markdown]
# #### 2.3.1 Add-one (Laplace) smoothing

# %% [markdown]
# **Code**
#
# \# todo

# %%
train = PlaintextCorpusReader("./","train.txt")
sents = train.sents()

# uni_train,_ = preprocessing.padded_everygram_pipeline(1,sents)
bi_train,_  = preprocessing.padded_everygram_pipeline(2,sents)
# tri_train,_ = preprocessing.padded_everygram_pipeline(3,sents)

# uni_Laplace_model = lm.Laplace(1)
bi_Laplace_model  = lm.Laplace(2)
# tri_Laplace_model = lm.Laplace(3)

# uni_Laplace_model.fit(uni_train,vocab)
bi_Laplace_model.fit(bi_train,vocab)
# tri_Laplace_model.fit(tri_train,vocab)

# %%
train = PlaintextCorpusReader("./","train.txt")
sents = train.sents()

# uni_train,_ = preprocessing.padded_everygram_pipeline(1,sents)
bi_train,_  = preprocessing.padded_everygram_pipeline(2,sents)
# tri_train,_ = preprocessing.padded_everygram_pipeline(3,sents)

ppl = []
for sent in bi_train:
    ppl.append(bi_Laplace_model.perplexity(list(sent)))
# ppl_mean = np.mean(ppl)
ppl_mean = gmean(ppl)
print("Perplexity of Bigram Model over train dataset:",ppl_mean)
# Out:
# Perplexity of Bigram Model over train dataset: 799.5663817970321

# %%
test  = PlaintextCorpusReader("./","dev.txt")
sents = test.sents()

# uni_dev,_ = preprocessing.padded_everygram_pipeline(1,sents)
bi_dev,_  = preprocessing.padded_everygram_pipeline(2,sents)
# tri_dev,_ = preprocessing.padded_everygram_pipeline(3,sents)

ppl = []
for sent in bi_dev:
    ppl.append(bi_Laplace_model.perplexity(list(sent)))
# ppl_mean = np.mean(ppl)
ppl_mean = gmean(ppl)
print("Perplexity of Bigram Model over dev dataset:",ppl_mean)
# Out:
# Perplexity of Bigram Model over dev dataset: 885.955985029454

# %% [markdown]
# **Discussion**
#
# \# todo
#
# After Add-one smoothing, Bigram Model's perplexity is 799.5663817970321 and 885.955985029454 over train dataset and dev dataset, respectively.
#
# Both of these two values are smaller than those of the un-smoothed Bigram Model in the last section.

# %% [markdown]
# #### 2.3.2: Add-$k$ smoothing

# %% [markdown]
# **Code**
#
# \# todo

# %%
train = PlaintextCorpusReader("./","train.txt")
sents = train.sents()

# uni_train,_ = preprocessing.padded_everygram_pipeline(1,sents)
bi_train,_  = preprocessing.padded_everygram_pipeline(2,sents)
# tri_train,_ = preprocessing.padded_everygram_pipeline(3,sents)
g = 0.5

# uni_Lidstone_model = lm.Lidstone(g,1,vocabulary=vocab)
bi_Lidstone_model  = lm.Lidstone(g,2,vocabulary=vocab)
# tri_Lidstone_model = lm.Lidstone(g,3,vocabulary=vocab)

# uni_Lidstone_model.fit(uni_train)
bi_Lidstone_model.fit(bi_train)
# tri_Lidstone_model.fit(tri_train)

test  = PlaintextCorpusReader("./","dev.txt")
sents = test.sents()

# uni_dev,_ = preprocessing.padded_everygram_pipeline(1,sents)
bi_dev,_  = preprocessing.padded_everygram_pipeline(2,sents)
# tri_dev,_ = preprocessing.padded_everygram_pipeline(3,sents)

ppl = []
for sent in bi_dev:
    ppl.append(bi_Lidstone_model.perplexity(list(sent)))
# ppl_mean = np.mean(ppl)
ppl_mean = gmean(ppl)
print(f"Perplexity of Bigram Model over dev dataset when gamma is {g}:",ppl_mean)
# Out:
# Perplexity of Bigram Model over dev dataset when gamma is 0.5: 758.5314311570586

# %%
train = PlaintextCorpusReader("./","train.txt")
sents = train.sents()

# uni_train,_ = preprocessing.padded_everygram_pipeline(1,sents)
bi_train,_  = preprocessing.padded_everygram_pipeline(2,sents)
# tri_train,_ = preprocessing.padded_everygram_pipeline(3,sents)
g = 0.05

# uni_Lidstone_model = lm.Lidstone(g,1,vocabulary=vocab)
bi_Lidstone_model  = lm.Lidstone(g,2,vocabulary=vocab)
# tri_Lidstone_model = lm.Lidstone(g,3,vocabulary=vocab)

# uni_Lidstone_model.fit(uni_train)
bi_Lidstone_model.fit(bi_train)
# tri_Lidstone_model.fit(tri_train)

test  = PlaintextCorpusReader("./","dev.txt")
sents = test.sents()

# uni_dev,_ = preprocessing.padded_everygram_pipeline(1,sents)
bi_dev,_  = preprocessing.padded_everygram_pipeline(2,sents)
# tri_dev,_ = preprocessing.padded_everygram_pipeline(3,sents)

ppl = []
for sent in bi_dev:
    ppl.append(bi_Lidstone_model.perplexity(list(sent)))
# ppl_mean = np.mean(ppl)
ppl_mean = gmean(ppl)
print(f"Perplexity of Bigram Model over dev dataset when gamma is {g}:",ppl_mean)
# Out:
# Perplexity of Bigram Model over dev dataset when gamma is 0.05: 512.8467604417024

# %%
train = PlaintextCorpusReader("./","train.txt")
sents = train.sents()

# uni_train,_ = preprocessing.padded_everygram_pipeline(1,sents)
bi_train,_  = preprocessing.padded_everygram_pipeline(2,sents)
# tri_train,_ = preprocessing.padded_everygram_pipeline(3,sents)
g = 0.01

# uni_Lidstone_model = lm.Lidstone(g,1,vocabulary=vocab)
bi_Lidstone_model  = lm.Lidstone(g,2,vocabulary=vocab)
# tri_Lidstone_model = lm.Lidstone(g,3,vocabulary=vocab)

# uni_Lidstone_model.fit(uni_train)
bi_Lidstone_model.fit(bi_train)
# tri_Lidstone_model.fit(tri_train)

test  = PlaintextCorpusReader("./","dev.txt")
sents = test.sents()

# uni_dev,_ = preprocessing.padded_everygram_pipeline(1,sents)
bi_dev,_  = preprocessing.padded_everygram_pipeline(2,sents)
# tri_dev,_ = preprocessing.padded_everygram_pipeline(3,sents)

ppl = []
for sent in bi_dev:
    ppl.append(bi_Lidstone_model.perplexity(list(sent)))
# ppl_mean = np.mean(ppl)
ppl_mean = gmean(ppl)
print(f"Perplexity of Bigram Model over dev dataset when gamma is {g}:",ppl_mean)
# Out:
# Perplexity of Bigram Model over dev dataset when gamma is 0.01: 449.62736817084533

# %% [markdown]
# **Discussion**
#
# \# todo
#
# As shown above, the perplexity of Bigram Model over dev dataset when k is
#
# 0.5, 0.05, 0.01 is
#
# 758.5314311570586,
#
# 512.8467604417024 and
#
# 449.62736817084533, respectively.
#
# All of them are smaller than the perplexity of Bigram Model with add-one smoothing in the last section.

# %% [markdown]
# #### 2.3.3 Linear Interpolation

# %% [markdown]
# **Code**
#
# \# todo

# %%
train = PlaintextCorpusReader("./","train.txt")
sents = train.sents()

uni_train,_ = preprocessing.padded_everygram_pipeline(1,sents)
bi_train,_  = preprocessing.padded_everygram_pipeline(2,sents)
tri_train,_ = preprocessing.padded_everygram_pipeline(3,sents)
a = 0.4

uni_StupidBackoff_model = lm.StupidBackoff(alpha=a,order=1,vocabulary=vocab)
bi_StupidBackoff_model  = lm.StupidBackoff(alpha=a,order=2,vocabulary=vocab)
tri_StupidBackoff_model = lm.StupidBackoff(alpha=a,order=3,vocabulary=vocab)

uni_StupidBackoff_model.fit(uni_train)
bi_StupidBackoff_model.fit(bi_train)
tri_StupidBackoff_model.fit(tri_train)

# %%
train = PlaintextCorpusReader("./","train.txt")
sents = train.sents()
uni_train,_ = preprocessing.padded_everygram_pipeline(1,sents)
bi_train,_  = preprocessing.padded_everygram_pipeline(2,sents)
tri_train,_ = preprocessing.padded_everygram_pipeline(3,sents)

# Unigram
ppl = []
for sent in uni_train:
    ppl.append(uni_StupidBackoff_model.perplexity(list(sent)))
# ppl_mean = np.mean(ppl)
ppl_mean = gmean(ppl)
print(f"Perplexity of Unigram Model over train dataset when alpha is {a}:",ppl_mean)

# Bigram
ppl = []
for sent in bi_train:
    ppl.append(bi_StupidBackoff_model.perplexity(list(sent)))
# ppl_mean = np.mean(ppl)
ppl_mean = gmean(ppl)
print(f"Perplexity of Bigram Model over train dataset when alpha is {a}:",ppl_mean)

# Trigram
ppl = []
for sent in tri_train:
    ppl.append(tri_StupidBackoff_model.perplexity(list(sent)))
# ppl_mean = np.mean(ppl)
ppl_mean = gmean(ppl)
print(f"Perplexity of Trigram Model over train dataset when alpha is {a}:",ppl_mean)
# Out:
# Perplexity of Unigram Model over train dataset when alpha is 0.4: 977.7254663002035
# Perplexity of Bigram Model over train dataset when alpha is 0.4: 216.62822602581886
# Perplexity of Trigram Model over train dataset when alpha is 0.4: 57.53778400254985

# %%
test  = PlaintextCorpusReader("./","dev.txt")
sents = test.sents()
uni_dev,_ = preprocessing.padded_everygram_pipeline(1,sents)
bi_dev,_  = preprocessing.padded_everygram_pipeline(2,sents)
tri_dev,_ = preprocessing.padded_everygram_pipeline(3,sents)

# Unigram
ppl = []
for sent in uni_dev:
    ppl.append(uni_StupidBackoff_model.perplexity(list(sent)))
# ppl_mean = np.mean(ppl)
ppl_mean = gmean(ppl)
print(f"Perplexity of Unigram Model over dev dataset when alpha is {a}:",ppl_mean)

# Bigram
ppl = []
for sent in bi_dev:
    ppl.append(bi_StupidBackoff_model.perplexity(list(sent)))
# ppl_mean = np.mean(ppl)
ppl_mean = gmean(ppl)
print(f"Perplexity of Bigram Model over dev dataset when alpha is {a}:",ppl_mean)

# Trigram
ppl = []
for sent in tri_dev:
    ppl.append(tri_StupidBackoff_model.perplexity(list(sent)))
# ppl_mean = np.mean(ppl)
ppl_mean = gmean(ppl)
print(f"Perplexity of Trigram Model over dev dataset when alpha is {a}:",ppl_mean)
# Out:
# Perplexity of Unigram Model over dev dataset when alpha is 0.4: 945.1187134309084
# Perplexity of Bigram Model over dev dataset when alpha is 0.4: 338.8204045373383
# Perplexity of Trigram Model over dev dataset when alpha is 0.4: 205.61093312112462

# %%
for aa in range(1,10,2):
    a = aa/10
    train = PlaintextCorpusReader("./","train.txt")
    sents = train.sents()

    uni_train,_ = preprocessing.padded_everygram_pipeline(1,sents)
    # bi_train,_  = preprocessing.padded_everygram_pipeline(2,sents)
    # tri_train,_ = preprocessing.padded_everygram_pipeline(3,sents)

    uni_StupidBackoff_model = lm.StupidBackoff(alpha=a,order=1,vocabulary=vocab)
    # bi_StupidBackoff_model  = lm.StupidBackoff(alpha=a,order=2,vocabulary=vocab)
    # tri_StupidBackoff_model = lm.StupidBackoff(alpha=a,order=3,vocabulary=vocab)

    uni_StupidBackoff_model.fit(uni_train)
    # bi_StupidBackoff_model.fit(bi_train)
    # tri_StupidBackoff_model.fit(tri_train)

    test  = PlaintextCorpusReader("./","dev.txt")
    sents = test.sents()
    uni_dev,_ = preprocessing.padded_everygram_pipeline(1,sents)
    # bi_dev,_  = preprocessing.padded_everygram_pipeline(2,sents)
    # tri_dev,_ = preprocessing.padded_everygram_pipeline(3,sents)

    ppl = []
    for sent in uni_dev:
        ppl.append(uni_StupidBackoff_model.perplexity(list(sent)))
    # ppl_mean = np.mean(ppl)
    ppl_mean = gmean(ppl)
    print(f"Perplexity of Unigram Model over dev dataset when alpha is {a}:",ppl_mean)
# Out:
# Perplexity of Unigram Model over dev dataset when alpha is 0.1: 945.1187134309084
# Perplexity of Unigram Model over dev dataset when alpha is 0.3: 945.1187134309084
# Perplexity of Unigram Model over dev dataset when alpha is 0.5: 945.1187134309084
# Perplexity of Unigram Model over dev dataset when alpha is 0.7: 945.1187134309084
# Perplexity of Unigram Model over dev dataset when alpha is 0.9: 945.1187134309084

# %%
for aa in range(1,10,2):
    a = aa/10
    train = PlaintextCorpusReader("./","train.txt")
    sents = train.sents()

    # uni_train,_ = preprocessing.padded_everygram_pipeline(1,sents)
    bi_train,_  = preprocessing.padded_everygram_pipeline(2,sents)
    # tri_train,_ = preprocessing.padded_everygram_pipeline(3,sents)

    # uni_StupidBackoff_model = lm.StupidBackoff(alpha=a,order=1,vocabulary=vocab)
    bi_StupidBackoff_model  = lm.StupidBackoff(alpha=a,order=2,vocabulary=vocab)
    # tri_StupidBackoff_model = lm.StupidBackoff(alpha=a,order=3,vocabulary=vocab)

    # uni_StupidBackoff_model.fit(uni_train)
    bi_StupidBackoff_model.fit(bi_train)
    # tri_StupidBackoff_model.fit(tri_train)

    test  = PlaintextCorpusReader("./","dev.txt")
    sents = test.sents()
    # uni_dev,_ = preprocessing.padded_everygram_pipeline(1,sents)
    bi_dev,_  = preprocessing.padded_everygram_pipeline(2,sents)
    # tri_dev,_ = preprocessing.padded_everygram_pipeline(3,sents)

    ppl = []
    for sent in bi_dev:
        ppl.append(bi_StupidBackoff_model.perplexity(list(sent)))
    # ppl_mean = np.mean(ppl)
    ppl_mean = gmean(ppl)
    print(f"Perplexity of Bigram Model over dev dataset when alpha is {a}:",ppl_mean)
# Out:
# Perplexity of Bigram Model over dev dataset when alpha is 0.1: 384.1621036225339
# Perplexity of Bigram Model over dev dataset when alpha is 0.3: 347.7672326137989
# Perplexity of Bigram Model over dev dataset when alpha is 0.5: 332.0395208219873
# Perplexity of Bigram Model over dev dataset when alpha is 0.7: 322.0705270560666
# Perplexity of Bigram Model over dev dataset when alpha is 0.9: 314.82035041825503

# %%
for aa in range(1,10,2):
    a = aa/10
    train = PlaintextCorpusReader("./","train.txt")
    sents = train.sents()

    # uni_train,_ = preprocessing.padded_everygram_pipeline(1,sents)
    # bi_train,_  = preprocessing.padded_everygram_pipeline(2,sents)
    tri_train,_ = preprocessing.padded_everygram_pipeline(3,sents)

    # uni_StupidBackoff_model = lm.StupidBackoff(alpha=a,order=1,vocabulary=vocab)
    # bi_StupidBackoff_model  = lm.StupidBackoff(alpha=a,order=2,vocabulary=vocab)
    tri_StupidBackoff_model = lm.StupidBackoff(alpha=a,order=3,vocabulary=vocab)

    # uni_StupidBackoff_model.fit(uni_train)
    # bi_StupidBackoff_model.fit(bi_train)
    tri_StupidBackoff_model.fit(tri_train)

    test  = PlaintextCorpusReader("./","dev.txt")
    sents = test.sents()
    # uni_dev,_ = preprocessing.padded_everygram_pipeline(1,sents)
    # bi_dev,_  = preprocessing.padded_everygram_pipeline(2,sents)
    tri_dev,_ = preprocessing.padded_everygram_pipeline(3,sents)

    ppl = []
    for sent in tri_dev:
        ppl.append(tri_StupidBackoff_model.perplexity(list(sent)))
    # ppl_mean = np.mean(ppl)
    ppl_mean = gmean(ppl)
    print(f"Perplexity of Trigram Model over dev dataset when alpha is {a}:",ppl_mean)
# Out:
# Perplexity of Trigram Model over dev dataset when alpha is 0.1: 301.7857806636453
# Perplexity of Trigram Model over dev dataset when alpha is 0.3: 222.65360786315298
# Perplexity of Trigram Model over dev dataset when alpha is 0.5: 193.29522779487237
# Perplexity of Trigram Model over dev dataset when alpha is 0.7: 176.10525602129067
# Perplexity of Trigram Model over dev dataset when alpha is 0.9: 164.2709241815869

# %%
train = PlaintextCorpusReader("./","train.txt")
sents = train.sents()

# uni_train,_ = preprocessing.padded_everygram_pipeline(1,sents)
# bi_train,_  = preprocessing.padded_everygram_pipeline(2,sents)
tri_train,_ = preprocessing.padded_everygram_pipeline(3,sents)
a = 0.4

# uni_StupidBackoff_model = lm.StupidBackoff(alpha=a,order=1,vocabulary=vocab)
# bi_StupidBackoff_model  = lm.StupidBackoff(alpha=a,order=2,vocabulary=vocab)
tri_StupidBackoff_model = lm.StupidBackoff(alpha=a,order=3,vocabulary=vocab)

# uni_StupidBackoff_model.fit(uni_train)
# bi_StupidBackoff_model.fit(bi_train)
tri_StupidBackoff_model.fit(tri_train)

test  = PlaintextCorpusReader("./","test.txt")
sents = test.sents()
# uni_test,_ = preprocessing.padded_everygram_pipeline(1,sents)
# bi_test,_  = preprocessing.padded_everygram_pipeline(2,sents)
tri_test,_ = preprocessing.padded_everygram_pipeline(3,sents)

ppl = []
for sent in tri_test:
    ppl.append(tri_StupidBackoff_model.perplexity(list(sent)))
# ppl_mean = np.mean(ppl)
ppl_mean = gmean(ppl)
print(f"Perplexity of Trigram Model over test dataset when alpha is {a}:",ppl_mean)
# Out:
# Perplexity of Trigram Model over test dataset when alpha is 0.4: 201.71390470123558

# %% [markdown]
# **Discussion**
#
# \# todo
#
# When alpha is 0.4, the perplexity of Unigram Model over train dataset and dev dataset is 977.7254663002035 and 945.1187134309084 respectively.
#
# When alpha is 0.4, the perplexity of Bigram Model over train dataset and dev dataset is 216.62822602581886 and 338.8204045373383 respectively.
#
# When alpha is 0.4, the perplexity of Trigram Model over train dataset and dev dataset is 57.53778400254985 and 205.61093312112462 respectively.
#
# Results of optimizing on a dev set by trying different hyperparameter sets are shown below:
#
# Perplexity of Unigram Model over dev dataset:
#
# when alpha is 0.1: 945.1187134309084
#
# when alpha is 0.3: 945.1187134309084
#
# when alpha is 0.5: 945.1187134309084
#
# when alpha is 0.7: 945.1187134309084
#
# when alpha is 0.9: 945.1187134309084
#
# Perplexity of Bigram Model over dev dataset:
#
# when alpha is 0.1: 384.1621036225339
#
# when alpha is 0.3: 347.7672326137989
#
# when alpha is 0.5: 332.0395208219873
#
# when alpha is 0.7: 322.0705270560666
#
# when alpha is 0.9: 314.82035041825503
#
# Perplexity of Trigram Model over dev dataset:
#
# when alpha is 0.1: 301.7857806636453
#
# when alpha is 0.3: 222.65360786315298
#
# when alpha is 0.5: 193.29522779487237
#
# when alpha is 0.7: 176.10525602129067
#
# when alpha is 0.9: 164.2709241815869
#
# As shown above, changing parameter alpha does make a difference in the value of perplexity, however, according to the description from nltk, "In addition to initialization arguments from BaseNgramModel also requires a parameter alpha with which we scale the lower order probabilities. Note that this is not a true probability distribution as scores for ngrams of the same order do not sum up to unity.", changing alpha's value does not result in better model performance.
#
# I have tried different alpha, and the results also demonstrated that changing alpha cannot improve thr model's performance significantly. And the default value of alpha, namely 0.4, is good enough.

# %% [markdown]
# ##### **Optimization**:
#
# \# todo

# %% [markdown]
# ## 3 Preposition Prediction

# %%
# !wget -O dev.in https://raw.githubusercontent.com/qtli/COMP7607-Fall2023/master/assignments/A1/data/prep/dev.in
# !wget -O dev.out https://raw.githubusercontent.com/qtli/COMP7607-Fall2023/master/assignments/A1/data/prep/dev.out
# !wget -O test.in https://raw.githubusercontent.com/qtli/COMP7607-Fall2023/master/assignments/A1/data/prep/test.in
# Out:
# --2023-10-21 01:59:02--  https://raw.githubusercontent.com/qtli/COMP7607-Fall2023/master/assignments/A1/data/prep/dev.in
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 210427 (205K) [text/plain]
# Saving to: ‘dev.in’
#
# dev.in              100%[===================>] 205.50K  --.-KB/s    in 0.02s
#
# 2023-10-21 01:59:02 (10.9 MB/s) - ‘dev.in’ saved [210427/210427]
#
# --2023-10-21 01:59:02--  https://raw.githubusercontent.com/qtli/COMP7607-Fall2023/master/assignments/A1/data/prep/dev.out
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10018 (9.8K) [text/plain]
# Saving to: ‘dev.out’
#
# dev.out             100%[===================>]   9.78K  --.-KB/s    in 0s
#
# 2023-10-21 01:59:02 (54.9 MB/s) - ‘dev.out’ saved [10018/10018]
#
# --2023-10-21 01:59:02--  https://raw.githubusercontent.com/qtli/COMP7607-Fall2023/master/assignments/A1/data/prep/test.in
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68304 (67K) [text/plain]
# Saving to: ‘test.in’
#
# test.in             100%[===================>]  66.70K  --.-KB/s    in 0.01s
#
# 2023-10-21 01:59:03 (4.54 MB/s) - ‘test.in’ saved [68304/68304]

# %%
test = PlaintextCorpusReader("./","dev.in")
sents = test.sents()
f = open("./dd.out","w+")
options = ["at", "in", "of", "for", "on"]

for sent in sents:
    for i in range(len(sent)):
        if sent[i] == "PREP":
            max = 0
            # min = 1e9
            for o in options:
              score = tri_StupidBackoff_model.score(o,[sent[i-3],sent[i-2]])
              if score > max:
                max = score
                ans = o
            print(ans,end=" ")
            f.write(str(ans)+" ")
    print("\n")
    f.write("\n")
f.close()
# Out:
# on of in at
#
# of
#
# of
#
# in of on
#
# of in for on
#
# at in
#
# on
#
# of in in of of
#
# on of in
#
# in
#
# in
#
# of in of in
#
# of
#
# in for
#
# of on
#
# in of
#
# in of
#
# in of
#
# at in of
#
# of at in on in
#
# in in of
#
# in of of in
#
# on for of
#
# in in for of for
#
# at in of
#
# in
#
# at
#
# in in in of
#
# in in on
#
# of
#
# on on in
#
# in of
#
# on in
#
# in on
#
# in of
#
# of of
#
# in of
#
# in
#
# in in
#
# in of in of
#
# on of on
#
# of on
#
# in of in of
#
# in in in
#
# in
#
# in of in of
#
# on in in of
#
# on
#
# of
#
# of of
#
# in of
#
# in
#
# of in for in in
#
# in of on of on
#
# in on
#
# in in
#
# in
#
# at in
#
# on of in of
#
# on of on
#
# in on
#
# in in of
#
# of in in
#
# of on in
#
# of in in
#
# in on of on
#
# in
#
# on
#
# in
#
# of
#
# on
#
# on on
#
# of
#
# in of on in
#
# in for in for
#
# on for on on
#
# in in
#
# on in
#
# of
#
# in for in on in
#
# on of in on in on of in
#
# in for in for
#
# on of
#
# on of in
#
# of of in
#
# on in in on
#
# on of in
#
# of in
#
# of of
#
# of at of in
#
# in for
#
# of of in
#
# of
#
# in in
#
# in on
#
# on in of
#
# in
#
# in
#
# in in in
#
# in at
#
# of
#
# in of in
#
# for
#
# in on in for of of
#
# on of on
#
# on in of
#
# in in
#
# of in
#
# on for
#
# of in on of in
#
# in of in of for
#
# in
#
# in
#
# of of in of on
#
# in
#
# of in at
#
# in in
#
# of of
#
# at
#
# on of
#
# of of
#
# of
#
# on
#
# of of of in
#
# on
#
# for
#
# of in
#
# in
#
# in in
#
# of in of on
#
# of
#
# in for of in of of
#
# in in in of of
#
# of
#
# in
#
# in
#
# at
#
# on of in
#
# on
#
# for of on of in
#
# on
#
# of on
#
# for
#
# on of in in
#
# of on
#
# of on
#
# on
#
# at
#
# of on
#
# on
#
# in
#
# in of
#
# on in of for
#
# of
#
# for in
#
# on at
#
# in in on of
#
# on in for in
#
# of at of in
#
# in in on in in
#
# for of
#
# on in
#
# on in of
#
# on in of
#
# on in of
#
# in of of in of
#
# on in
#
# in in
#
# on on
#
# of for in in of
#
# on
#
# on
#
# on in of
#
# in in of
#
# in
#
# in in of on
#
# in
#
# in on of on on
#
# on for
#
# of in of of of
#
# in for on
#
# of on
#
# for in
#
# in
#
# of
#
# on
#
# in
#
# of in of
#
# of
#
# in in
#
# on for of
#
# of
#
# on
#
# on of in
#
# of of
#
# for on in in of
#
# in in
#
# of for
#
# in in
#
# of in in for in
#
# of of for
#
# in in for
#
# in of on of
#
# in
#
# for in on
#
# on for of in of
#
# on in in
#
# in
#
# of of
#
# of in on
#
# of in
#
# in on in of
#
# in in of
#
# at in in of of
#
# in in for
#
# for of on
#
# of on on
#
# of
#
# on of in at
#
# on
#
# in of in of
#
# in
#
# for in of of in
#
# in on
#
# in for in for of
#
# of in
#
# on of
#
# on of
#
# in of in of
#
# in for
#
# in on of
#
# of in in
#
# in of on
#
# in of of
#
# of in in
#
# of on in in of of
#
# on in
#
# on in in of on
#
# of in in
#
# in
#
# of of in of
#
# for
#
# in
#
# of
#
# in in
#
# of in in
#
# in in of in of
#
# on
#
# on
#
# in on
#
# on of in
#
# on in for for
#
# in in
#
# at of in
#
# on
#
# in
#
# in
#
# in in on
#
# on on in
#
# of for
#
# of
#
# for on
#
# in in in
#
# in in on in of
#
# in in
#
# at of
#
# of in
#
# of in of
#
# on
#
# in at
#
# of
#
# of
#
# on in of of
#
# in in
#
# of in
#
# in
#
# on on
#
# in in
#
# of in in on
#
# in of of in of of
#
# at
#
# in
#
# of in of
#
# of of in
#
# in in
#
# in
#
# in for
#
# in in
#
# in on
#
# at in of
#
# of
#
# on in in for
#
# in
#
# in in of
#
# of in for
#
# of
#
# in
#
# in
#
# of
#
# in of in in of
#
# in on on of
#
# on in
#
# in in in
#
# in of
#
# of for
#
# on in in in
#
# of in on
#
# on on on
#
# in
#
# in of on
#
# in in
#
# of in in in
#
# at in of
#
# in
#
# in on on for
#
# in of
#
# in
#
# in in
#
# of
#
# in in on in
#
# in in on
#
# in of in
#
# in in
#
# of in
#
# on
#
# in on in
#
# in for on
#
# for in
#
# on in
#
# on
#
# in of
#
# in of of in in
#
# in in
#
# for
#
# in of of
#
# in of in for
#
# of for of
#
# of in
#
# of of for
#
# of
#
# of in in
#
# in on on on in of of
#
# of in
#
# for of of on
#
# in of
#
# on in
#
# on
#
# in for in for in of
#
# on
#
# for in in in in
#
# on in
#
# on of on at
#
# in
#
# in in
#
# in
#
# in at
#
# on in
#
# in
#
# of in
#
# of in of
#
# in in
#
# in
#
# in in of
#
# in
#
# in in in in for
#
# of in
#
# in on
#
# in on at
#
# in
#
# in
#
# in on at
#
# of in
#
# of of of
#
# in in
#
# in
#
# of of in
#
# on
#
# in
#
# in on of
#
# of for
#
# on of in
#
# in on on
#
# in on of for
#
# in
#
# in of in
#
# in on on
#
# of
#
# in in of
#
# in
#
# in
#
# in
#
# of on in
#
# of on
#
# of in of
#
# of in in
#
# of in of
#
# of in of for
#
# on of on
#
# on of of in of
#
# on in on on
#
# of in of for
#
# of in in
#
# of in of in in in on
#
# in on of
#
# of in in of of
#
# in
#
# of in on
#
# in in
#
# on of on
#
# on on
#
# in in of of
#
# in in
#
# in
#
# of in of
#
# in of
#
# of of in
#
# of in of in of
#
# in of
#
# in in of
#
# in in
#
# of on
#
# in in
#
# on in in in of
#
# in of
#
# in of of
#
# in
#
# on in
#
# in in of
#
# of in on
#
# on of
#
# of
#
# in for of
#
# in
#
# of
#
# in of
#
# of
#
# on of
#
# of
#
# in
#
# for in on
#
# of of for
#
# of on in of
#
# in on on
#
# of of of of
#
# in in
#
# on in
#
# in
#
# of in of
#
# in on of of
#
# of on of of
#
# for
#
# in
#
# on on
#
# in on on
#
# for in in on of of
#
# for
#
# on of in
#
# in in on of
#
# of of
#
# in of for
#
# on in of
#
# of for on in
#
# for in on
#
# for in in on of of
#
# on of on
#
# in in on
#
# in for on
#
# of of of
#
# in of in of
#
# in of in
#
# at in of
#
# in of of
#
# in on in on
#
# for of on
#
# of in
#
# of on on
#
# of in in
#
# in of in in in on
#
# on for of
#
# in on on
#
# on of
#
# in in
#
# of for in
#
# of of in
#
# in
#
# of in in in
#
# for in of for of
#
# in in in
#
# of at of for
#
# in
#
# in in in
#
# on of in in of of
#
# of in of for
#
# of in of
#
# of in
#
# of in in
#
# on on of
#
# on
#
# of in in
#
# for in
#
# of on
#
# of
#
# in
#
# of in
#
# in in in
#
# of in
#
# in
#
# on of in
#
# in of
#
# for of
#
# of in in for
#
# for of in on
#
# in in
#
# in in of on
#
# of of of
#
# of on
#
# of on
#
# of for of
#
# in
#
# for in on
#
# in
#
# in in
#
# of in of
#
# in of
#
# in
#
# for
#
# of at for in
#
# in in of of
#
# on in
#
# of in of on
#
# for in
#
# in in
#
# in
#
# in in
#
# of in of
#
# for of of
#
# for for
#
# in on for of
#
# on
#
# in in
#
# of in of in of
#
# of of in
#
# of
#
# on of in
#
# of in on in in
#
# of on in in of
#
# for
#
# on of on on
#
# in in in of on
#
# in of
#
# of in on in in
#
# in in
#
# in of
#
# for
#
# for on of
#
# in in of
#
# in in
#
# for for
#
# in in in in at in
#
# in in
#
# of on
#
# in in in
#
# of in in
#
# of
#
# in of of
#
# on in
#
# for
#
# in in
#
# in
#
# in of
#
# in
#
# of in in in
#
# on
#
# in of of in
#
# in in
#
# in on of
#
# on for in
#
# in of
#
# on in on of
#
# of
#
# on of
#
# in
#
# in for in
#
# of for
#
# of
#
# of
#
# on in
#
# in
#
# on
#
# in of of of
#
# in in in in
#
# in in of in
#
# of on in
#
# in of in in
#
# for on
#
# in of
#
# in
#
# of in
#
# in for in
#
# on on
#
# of
#
# on of
#
# in for in
#
# on of
#
# in of
#
# of in
#
# of in
#
# of in in
#
# in
#
# on in
#
# in of of
#
# on in for in
#
# in for
#
# of
#
# of
#
# of on in in
#
# in
#
# in of in of in
#
# of for
#
# for in
#
# in of of for
#
# of
#
# for in
#
# of in
#
# in of
#
# of
#
# in
#
# of on for
#
# on in of
#
# in on
#
# in
#
# in of of
#
# in
#
# of in in in
#
# in on
#
# on of on in on
#
# in
#
# in in in of
#
# of for
#
# on of
#
# in in
#
# in
#
# of of
#
# in
#
# in
#
# of
#
# in of in on in
#
# on at of
#
# in for on
#
# in of of on
#
# on for
#
# on
#
# of
#
# in
#
# on in
#
# in of in of
#
# in
#
# in
#
# on at of
#
# of
#
# on
#
# of in
#
# of in
#
# on for
#
# on in of at on
#
# in for on in
#
# of
#
# in of
#
# in on
#
# on on of
#
# of of
#
# on in
#
# in of on
#
# on
#
# in of on in
#
# on
#
# for
#
# in in
#
# in of
#
# in of
#
# of in on
#
# on
#
# of in in
#
# in in
#
# in of of
#
# of on
#
# on
#
# of of of at in
#
# of of
#
# on of
#
# on of on
#
# of of of of
#
# on for
#
# on on
#
# in in
#
# of
#
# in
#
# in
#
# on
#
# of in in
#
# in
#
# of
#
# in of
#
# on
#
# of
#
# on for of for in
#
# in
#
# in in on of in
#
# for of of in
#
# in on for
#
# of on
#
# of in
#
# on in in in
#
# in
#
# in in
#
# in in of on
#
# on in in
#
# in for in
#
# of on
#
# in
#
# in at
#
# of in on
#
# in
#
# of
#
# in
#
# in on
#
# in of of
#
# of of in on
#
# in
#
# on of on in of in on
#
# of on
#
# of of
#
# in of of in in of
#
# of
#
# in of
#
# on in in
#
# in
#
# in
#
# on
#
# in
#
# in
#
# of on of
#
# for in of
#
# in in
#
# of in for
#
# in of on of
#
# in
#
# on of
#
# in
#
# of for in of on
#
# in in
#
# at of
#
# of in on of in
#
# in in
#
# of in for
#
# in of in
#
# for in
#
# of
#
# in
#
# in in for for
#
# on in for of of
#
# of
#
# for in
#
# of in
#
# in of
#
# of of
#
# in in on in
#
# of of in at in
#
# on
#
# on of in
#
# of
#
# for of
#
# of on of in in
#
# for on of
#
# of in of
#
# in
#
# for for in
#
# of in of on
#
# of of in
#
# on for in
#
# on of
#
# for in
#
# of
#
# in in
#
# of in
#
# for in of
#
# in at
#
# at for
#
# on of of in on
#
# on in of
#
# in in for
#
# of in in
#
# of
#
# for in on of in
#
# in
#
# of on
#
# on of for of
#
# on of in
#
# in in
#
# of in
#
# of on of
#
# in of in
#
# on
#
# in of of on
#
# in of in of
#
# in in in
#
# for on on on of
#
# of
#
# in on
#
# in
#
# on of in
#
# of
#
# of of on
#
# of on
#
# in in
#
# in of
#
# of in in
#
# of
#
# in in
#
# for of on
#
# in in on
#
# in in on
#
# of of in of
#
# on in
#
# in
#
# in
#
# in
#
# in of
#
# in in
#
# of in of
#
# in in of for in
#
# in in
#
# for of
#
# on of
#
# of
#
# in
#
# for on
#
# at
#
# on
#
# in in
#
# of in in
#
# of of of
#
# in
#
# in of
#
# of
#
# in
#
# for
#
# on on for
#
# in
#
# in in on of for
#
# on for
#
# in of in of
#
# on
#
# on in of
#
# in in in
#
# of on
#
# of in
#
# of of in in on
#
# in in
#
# on of
#
# in of
#
# on in of
#
# in on in of in on
#
# in
#
# on on of
#
# of in on of
#
# for in of
#
# in of
#
# in
#
# in in
#
# in in on of
#
# on
#
# in of on
#
# in on on
#
# of in
#
# in
#
# in on
#
# in of in
#
# for
#
# of
#
# in in
#
# on
#
# of
#
# at on
#
# for
#
# of in on on
#
# in of
#
# in of in
#
# on of in in in
#
# for
#
# in in of
#
# of in
#
# on for
#
# for in at
#
# in
#
# in of
#
# on of in of of
#
# in at
#
# at
#
# in of in
#
# on of
#
# in for
#
# on
#
# of of in on
#
# in in
#
# on of
#
# at in in
#
# of in in of
#
# in on in of in on
#
# in in on
#
# on on
#
# in of
#
# for
#
# on for
#
# for of in in on
#
# in in in
#
# in of of of
#
# in in
#
# in for
#
# for of of in in
#
# on
#
# of in
#
# in in
#
# of in for
#
# in
#
# for for
#
# of of in
#
# of on
#
# in in of on
#
# in at on
#
# in at on
#
# in on on on
#
# in in of on
#
# of on in
#
# in
#
# at
#
# of on on on in
#
# of in on
#
# of for in
#
# in
#
# in at on
#
# in for on
#
# in on in
#
# in of on
#
# of of
#
# in of
#
# in in of
#
# of in
#
# in of
#
# on on
#
# for of in
#
# in on of of of in
#
# for
#
# for of in
#
# at of
#
# in in in in
#
# of for
#
# in in
#
# in at in
#
# on in in in
#
# in in of of of in
#
# of
#
# of in in
#
# for on of
#
# in in on
#
# in on in in on in
#
# on of on
#
# on
#
# of of in
#
# at in for
#
# of of of on
#
# for on in on
#
# in on on
#
# in in
#
# in
#
# in of
#
# in on for
#
# of of in of
#
# in in of
#
# of of of on
#
# in
#
# in of
#
# of on
#
# of in
#
# in for in in
#
# of of in in in
#
# for on in of
#
# in
#
# in on of in on
#
# in in
#
# in on of
#
# on
#
# for on in
#
# in
#
# of
#
# of in
#
# for on of in
#
# at of of in on at
#
# for for in in
#
# in in in of
#
# on
#
# on in on
#
# on on
#
# of on
#
# on
#
# for
#
# on in of
#
# in
#
# in of
#
# on of in in
#
# on
#
# of on
#
# on
#
# in
#
# in
#
# on for
#
# on in
#
# in
#
# of in
#
# of on in in for
#
# on on for for
#
# in in
#
# in of of
#
# in of
#
# on in in
#
# at at
#
# in on in
#
# on in
#
# on of in
#
# at for for of
#
# on in in of
#
# at of in for
#
# in of
#
# for
#
# on
#
# of
#
# in
#
# in in
#
# on of in on
#
# for
#
# of
#
# on
#
# on in in of
#
# on in
#
# of
#
# in for
#
# on of in in
#
# in of on
#
# for in on
#
# in
#
# in in
#
# for in in
#
# in for on
#
# in in
#
# of for in
#
# in of
#
# on in on
#
# on in
#
# on of in
#
# on in on in
#
# of of
#
# of for on
#
# in in
#
# in of in
#
# for on
#
# in of
#
# of
#
# of of
#
# in of on
#
# on of on of in
#
# in
#
# for of in
#
# in on on
#
# in
#
# on
#
# of
#
# of in
#
# on
#
# in
#
# on of
#
# in in of
#
# for
#
# in of
#
# on
#
# on in
#
# in
#
# in on in
#
# in of
#
# in for
#
# of
#
# in of of of
#
# in in in in of
#
# at on
#
# on of
#
# on for
#
# on of of for on
#
# for in
#
# on
#
# in
#
# of
#
# in of
#
# in in
#
# for
#
# on in on at
#
# in of
#
# of on in
#
# of
#
# on for
#
# in for
#
# of in for of in
#
# in
#
# in in in
#
# in for of
#
# in of in on
#
# for
#
# in of for
#
# in of
#
# of in
#
# in
#
# in in
#
# for on of in
#
# in in of in
#
# on on
#
# on
#
# in on for of
#
# on for
#
# of of
#
# in of in
#
# of in
#
# in
#
# on in in in
#
# on
#
# of of of
#
# on of of of
#
# in in
#
# of of
#
# in in of on
#
# of of on of
#
# of of
#
# in
#
# on
#
# on on on
#
# in of in
#
# on of of
#
# in at
#
# of of of
#
# of of
#
# in for of
#
# of in on of of
#
# in in of in
#
# of of
#
# for of in

# %%
import re
f = open("./dev.out","r")
gt = f.read()
gt = re.split(" |\n",gt)
gt = [g for g in gt if g != ""]
# print(len(gt))
print("Groundtruth:",end=" ")
print(gt)
f.close()

f = open("./dd.out","r")
p = f.read()
p = re.split(" |\n",p)

p = [pp for pp in p if pp != ""]
# print(len(p))
print("Prediction:",end=" ")
print(p)
f.close()

acc = (np.array(gt)==np.array(p)).mean()
print("Accuracy of prediction over dev dataset is",acc)
# Out:
# Groundtruth: ['on', 'of', 'in', 'in', 'of', 'of', 'in', 'of', 'for', 'of', 'in', 'for', 'on', 'at', 'in', 'on', 'of', 'in', 'in', 'on', 'of', 'on', 'on', 'in', 'on', 'on', 'of', 'on', 'of', 'in', 'in', 'for', 'in', 'of', 'on', 'in', 'of', 'on', 'of', 'in', 'of', 'on', 'for', 'of', 'of', 'at', 'on', 'at', 'on', 'in', 'of', 'of', 'of', 'in', 'on', 'on', 'on', 'for', 'of', 'in', 'in', 'at', 'of', 'for', 'on', 'for', 'of', 'on', 'at', 'of', 'on', 'in', 'of', 'of', 'in', 'on', 'at', 'on', 'on', 'in', 'in', 'of', 'on', 'on', 'in', 'of', 'in', 'of', 'on', 'of', 'on', 'of', 'in', 'in', 'in', 'at', 'of', 'at', 'of', 'on', 'of', 'in', 'of', 'on', 'for', 'for', 'in', 'of', 'on', 'at', 'on', 'on', 'on', 'of', 'for', 'in', 'of', 'in', 'on', 'of', 'on', 'of', 'of', 'for', 'in', 'of', 'on', 'of', 'in', 'for', 'in', 'in', 'at', 'of', 'in', 'of', 'in', 'in', 'on', 'in', 'in', 'in', 'at', 'on', 'at', 'of', 'in', 'of', 'in', 'on', 'in', 'in', 'for', 'for', 'of', 'of', 'at', 'in', 'at', 'of', 'on', 'in', 'at', 'in', 'at', 'on', 'for', 'at', 'in', 'on', 'on', 'in', 'at', 'in', 'on', 'on', 'of', 'on', 'of', 'on', 'in', 'on', 'for', 'in', 'for', 'for', 'for', 'in', 'of', 'for', 'in', 'in', 'of', 'of', 'in', 'of', 'in', 'on', 'in', 'for', 'in', 'of', 'for', 'at', 'on', 'of', 'at', 'on', 'for', 'in', 'for', 'on', 'of', 'in', 'of', 'of', 'of', 'of', 'in', 'on', 'of', 'of', 'at', 'for', 'of', 'for', 'of', 'at', 'in', 'of', 'of', 'on', 'of', 'at', 'in', 'for', 'of', 'of', 'at', 'of', 'in', 'of', 'in', 'of', 'for', 'of', 'of', 'of', 'of', 'on', 'of', 'in', 'in', 'at', 'of', 'in', 'of', 'in', 'of', 'of', 'at', 'on', 'for', 'in', 'of', 'on', 'of', 'in', 'in', 'on', 'of', 'on', 'in', 'of', 'of', 'on', 'in', 'of', 'in', 'for', 'of', 'at', 'for', 'of', 'on', 'of', 'of', 'on', 'on', 'of', 'of', 'at', 'of', 'on', 'in', 'of', 'in', 'for', 'of', 'in', 'at', 'of', 'at', 'on', 'of', 'of', 'in', 'of', 'on', 'of', 'of', 'of', 'in', 'on', 'for', 'of', 'on', 'in', 'on', 'in', 'of', 'in', 'of', 'on', 'of', 'in', 'of', 'of', 'in', 'of', 'of', 'of', 'at', 'in', 'of', 'of', 'of', 'in', 'on', 'at', 'on', 'of', 'of', 'in', 'of', 'in', 'on', 'of', 'in', 'in', 'of', 'in', 'for', 'on', 'of', 'in', 'of', 'of', 'in', 'of', 'in', 'on', 'on', 'of', 'in', 'on', 'for', 'in', 'of', 'on', 'of', 'of', 'for', 'at', 'on', 'in', 'on', 'at', 'in', 'at', 'on', 'of', 'in', 'for', 'for', 'on', 'of', 'at', 'of', 'for', 'in', 'of', 'for', 'in', 'in', 'on', 'on', 'in', 'on', 'for', 'in', 'of', 'for', 'in', 'of', 'in', 'on', 'of', 'in', 'of', 'on', 'in', 'of', 'for', 'in', 'at', 'in', 'on', 'on', 'on', 'of', 'on', 'for', 'at', 'on', 'on', 'in', 'on', 'of', 'of', 'at', 'of', 'in', 'in', 'at', 'of', 'on', 'on', 'in', 'in', 'of', 'on', 'on', 'on', 'of', 'in', 'in', 'of', 'of', 'for', 'in', 'for', 'for', 'of', 'at', 'in', 'in', 'in', 'of', 'in', 'on', 'of', 'in', 'of', 'of', 'on', 'on', 'on', 'for', 'of', 'of', 'in', 'in', 'on', 'in', 'on', 'of', 'of', 'for', 'in', 'in', 'of', 'on', 'in', 'of', 'for', 'of', 'of', 'of', 'on', 'on', 'in', 'in', 'of', 'of', 'for', 'in', 'on', 'in', 'for', 'of', 'in', 'of', 'on', 'for', 'at', 'on', 'on', 'for', 'of', 'in', 'of', 'on', 'in', 'for', 'in', 'of', 'of', 'of', 'on', 'in', 'of', 'for', 'on', 'in', 'in', 'for', 'on', 'on', 'of', 'for', 'on', 'of', 'in', 'of', 'on', 'on', 'on', 'in', 'of', 'on', 'in', 'for', 'on', 'of', 'in', 'of', 'on', 'in', 'on', 'in', 'of', 'in', 'of', 'in', 'for', 'in', 'on', 'of', 'on', 'at', 'in', 'on', 'at', 'in', 'of', 'of', 'of', 'in', 'in', 'in', 'in', 'in', 'in', 'of', 'in', 'of', 'on', 'for', 'in', 'in', 'in', 'of', 'in', 'in', 'in', 'of', 'in', 'of', 'of', 'of', 'of', 'in', 'in', 'of', 'for', 'of', 'in', 'of', 'in', 'on', 'in', 'on', 'in', 'for', 'of', 'at', 'of', 'on', 'of', 'on', 'of', 'of', 'in', 'of', 'on', 'in', 'of', 'in', 'at', 'of', 'in', 'in', 'in', 'on', 'of', 'on', 'of', 'on', 'in', 'on', 'on', 'in', 'of', 'in', 'in', 'in', 'for', 'for', 'for', 'in', 'on', 'of', 'at', 'on', 'in', 'in', 'in', 'for', 'on', 'on', 'on', 'for',  ...
# Prediction: ['on', 'of', 'in', 'at', 'of', 'of', 'in', 'of', 'on', 'of', 'in', 'for', 'on', 'at', 'in', 'on', 'of', 'in', 'in', 'of', 'of', 'on', 'of', 'in', 'in', 'in', 'of', 'in', 'of', 'in', 'of', 'in', 'for', 'of', 'on', 'in', 'of', 'in', 'of', 'in', 'of', 'at', 'in', 'of', 'of', 'at', 'in', 'on', 'in', 'in', 'in', 'of', 'in', 'of', 'of', 'in', 'on', 'for', 'of', 'in', 'in', 'for', 'of', 'for', 'at', 'in', 'of', 'in', 'at', 'in', 'in', 'in', 'of', 'in', 'in', 'on', 'of', 'on', 'on', 'in', 'in', 'of', 'on', 'in', 'in', 'on', 'in', 'of', 'of', 'of', 'in', 'of', 'in', 'in', 'in', 'in', 'of', 'in', 'of', 'on', 'of', 'on', 'of', 'on', 'in', 'of', 'in', 'of', 'in', 'in', 'in', 'in', 'in', 'of', 'in', 'of', 'on', 'in', 'in', 'of', 'on', 'of', 'of', 'of', 'in', 'of', 'in', 'of', 'in', 'for', 'in', 'in', 'in', 'of', 'on', 'of', 'on', 'in', 'on', 'in', 'in', 'in', 'at', 'in', 'on', 'of', 'in', 'of', 'on', 'of', 'on', 'in', 'on', 'in', 'in', 'of', 'of', 'in', 'in', 'of', 'on', 'in', 'of', 'in', 'in', 'in', 'on', 'of', 'on', 'in', 'on', 'in', 'of', 'on', 'on', 'on', 'of', 'in', 'of', 'on', 'in', 'in', 'for', 'in', 'for', 'on', 'for', 'on', 'on', 'in', 'in', 'on', 'in', 'of', 'in', 'for', 'in', 'on', 'in', 'on', 'of', 'in', 'on', 'in', 'on', 'of', 'in', 'in', 'for', 'in', 'for', 'on', 'of', 'on', 'of', 'in', 'of', 'of', 'in', 'on', 'in', 'in', 'on', 'on', 'of', 'in', 'of', 'in', 'of', 'of', 'of', 'at', 'of', 'in', 'in', 'for', 'of', 'of', 'in', 'of', 'in', 'in', 'in', 'on', 'on', 'in', 'of', 'in', 'in', 'in', 'in', 'in', 'in', 'at', 'of', 'in', 'of', 'in', 'for', 'in', 'on', 'in', 'for', 'of', 'of', 'on', 'of', 'on', 'on', 'in', 'of', 'in', 'in', 'of', 'in', 'on', 'for', 'of', 'in', 'on', 'of', 'in', 'in', 'of', 'in', 'of', 'for', 'in', 'in', 'of', 'of', 'in', 'of', 'on', 'in', 'of', 'in', 'at', 'in', 'in', 'of', 'of', 'at', 'on', 'of', 'of', 'of', 'of', 'on', 'of', 'of', 'of', 'in', 'on', 'for', 'of', 'in', 'in', 'in', 'in', 'of', 'in', 'of', 'on', 'of', 'in', 'for', 'of', 'in', 'of', 'of', 'in', 'in', 'in', 'of', 'of', 'of', 'in', 'in', 'at', 'on', 'of', 'in', 'on', 'for', 'of', 'on', 'of', 'in', 'on', 'of', 'on', 'for', 'on', 'of', 'in', 'in', 'of', 'on', 'of', 'on', 'on', 'at', 'of', 'on', 'on', 'in', 'in', 'of', 'on', 'in', 'of', 'for', 'of', 'for', 'in', 'on', 'at', 'in', 'in', 'on', 'of', 'on', 'in', 'for', 'in', 'of', 'at', 'of', 'in', 'in', 'in', 'on', 'in', 'in', 'for', 'of', 'on', 'in', 'on', 'in', 'of', 'on', 'in', 'of', 'on', 'in', 'of', 'in', 'of', 'of', 'in', 'of', 'on', 'in', 'in', 'in', 'on', 'on', 'of', 'for', 'in', 'in', 'of', 'on', 'on', 'on', 'in', 'of', 'in', 'in', 'of', 'in', 'in', 'in', 'of', 'on', 'in', 'in', 'on', 'of', 'on', 'on', 'on', 'for', 'of', 'in', 'of', 'of', 'of', 'in', 'for', 'on', 'of', 'on', 'for', 'in', 'in', 'of', 'on', 'in', 'of', 'in', 'of', 'of', 'in', 'in', 'on', 'for', 'of', 'of', 'on', 'on', 'of', 'in', 'of', 'of', 'for', 'on', 'in', 'in', 'of', 'in', 'in', 'of', 'for', 'in', 'in', 'of', 'in', 'in', 'for', 'in', 'of', 'of', 'for', 'in', 'in', 'for', 'in', 'of', 'on', 'of', 'in', 'for', 'in', 'on', 'on', 'for', 'of', 'in', 'of', 'on', 'in', 'in', 'in', 'of', 'of', 'of', 'in', 'on', 'of', 'in', 'in', 'on', 'in', 'of', 'in', 'in', 'of', 'at', 'in', 'in', 'of', 'of', 'in', 'in', 'for', 'for', 'of', 'on', 'of', 'on', 'on', 'of', 'on', 'of', 'in', 'at', 'on', 'in', 'of', 'in', 'of', 'in', 'for', 'in', 'of', 'of', 'in', 'in', 'on', 'in', 'for', 'in', 'for', 'of', 'of', 'in', 'on', 'of', 'on', 'of', 'in', 'of', 'in', 'of', 'in', 'for', 'in', 'on', 'of', 'of', 'in', 'in', 'in', 'of', 'on', 'in', 'of', 'of', 'of', 'in', 'in', 'of', 'on', 'in', 'in', 'of', 'of', 'on', 'in', 'on', 'in', 'in', 'of', 'on', 'of', 'in', 'in', 'in', 'of', 'of', 'in', 'of', 'for', 'in', 'of', 'in', 'in', 'of', 'in', 'in', 'in', 'in', 'of', 'in', 'of', 'on', 'on', 'in', 'on', 'on', 'of', 'in', 'on', 'in', 'for', 'for', 'in', 'in', 'at', 'of', 'in', 'on', 'in', 'in', 'in', 'in', 'on', 'on', 'on', 'in', 'of', 'for', 'of', 'for ...
# Accuracy of prediction over dev dataset is 0.611851332398317

# %%
test  = PlaintextCorpusReader("./","test.in")
sents = test.sents()

tri_test,_  = preprocessing.padded_everygram_pipeline(3,sents)


ppl = []
for sent in tri_test:
    ppl.append(tri_StupidBackoff_model.perplexity(list(sent)))
# ppl_mean = np.mean(ppl)
ppl_mean = gmean(ppl)
print(f"Perplexity of selected Trigram Model over test dataset:",ppl_mean)
# Out:
# Perplexity of selected Trigram Model over test dataset: 189.54784966775097

# %%
train = PlaintextCorpusReader("./","test.in")
sents = train.sents()
f = open("./3036198102.test.out","w+")
options = ["at", "in", "of", "for", "on"]

for sent in sents:
    for i in range(len(sent)):
        if sent[i] == "PREP":
            max = 0
            for o in options:
              score = tri_StupidBackoff_model.score(o,[sent[i-3],sent[i-2]])
              if score > max:
                max = score
                ans = o
            print(ans,end=" ")
            f.write(str(ans)+" ")
    print("\n")
    f.write("\n")
f.close()
# Out:
# of
#
# for in
#
# in
#
# of
#
# of for of
#
# in
#
# for in
#
# for at on
#
# in in of on
#
# on in
#
# of at
#
# on for
#
# in
#
# in in on
#
# in
#
# for of
#
# for of in of in
#
# for
#
# in of
#
# of in for in
#
# in of on
#
# for of on
#
# of in
#
# in in on of in
#
# of in
#
# on in of in
#
# on
#
# on for
#
# on on
#
# in of
#
# of for on
#
# on at on
#
# of
#
# of for
#
# for in
#
# of
#
# on of
#
# in of on in
#
# in
#
# for
#
# on in of
#
# in in
#
# in in for for
#
# for
#
# of in on
#
# for for
#
# in in
#
# of in in in
#
# in in
#
# on
#
# on of on in
#
# of in
#
# for in in
#
# in
#
# of in
#
# in of
#
# for in in of of
#
# in of of
#
# of in
#
# for
#
# in of in
#
# in
#
# in of of in
#
# of in
#
# on
#
# in
#
# in in of
#
# of of
#
# in
#
# in in
#
# for on
#
# in for of of
#
# of on of
#
# of for on
#
# of for
#
# on
#
# for
#
# in in for of
#
# of
#
# of of
#
# of of in
#
# for of
#
# on in of
#
# at of for in in
#
# for at of
#
# of in in
#
# in for in of in
#
# in in of
#
# in in
#
# on
#
# on
#
# of
#
# of
#
# of on for of
#
# of in
#
# in of in
#
# of in for in in
#
# for for in
#
# in of in
#
# on in
#
# of
#
# in
#
# at in
#
# in of on
#
# for in in
#
# for
#
# on
#
# on at of in of
#
# on
#
# in of
#
# of in in in
#
# on for
#
# on
#
# in
#
# in in
#
# in
#
# of
#
# of
#
# for of of on
#
# for
#
# in
#
# of
#
# in in in
#
# of of
#
# in
#
# of in
#
# of on
#
# of of
#
# in
#
# in in
#
# of
#
# on on on of of
#
# at
#
# of in
#
# in
#
# in
#
# in of for
#
# in of in
#
# in
#
# in of in
#
# for in of on of
#
# in in
#
# in
#
# of in of
#
# for in of of in on
#
# on on
#
# of in
#
# in in
#
# in of
#
# in for of of
#
# in of
#
# of
#
# of
#
# on on of
#
# on
#
# on on of
#
# on on
#
# in of
#
# on
#
# in
#
# of of
#
# of on
#
# in for of
#
# on in
#
# in
#
# in at of
#
# on at on
#
# of on
#
# of in in of on
#
# on of
#
# in for in on in
#
# in at
#
# on
#
# in of of in
#
# in
#
# of
#
# in
#
# on in in
#
# of of
#
# for in in in
#
# in in of
#
# in
#
# on of in
#
# in of on
#
# of of
#
# in of
#
# in for in in
#
# on in
#
# on in of
#
# on in
#
# on of
#
# on in
#
# in in in
#
# for
#
# for on for
#
# in
#
# of
#
# in in
#
# in
#
# for in at in
#
# in for
#
# on
#
# in of in
#
# in of
#
# for in
#
# in
#
# for
#
# in in for
#
# in
#
# in on
#
# for on for of
#
# in
#
# in in of
#
# in
#
# for for on of of in
#
# in
#
# in
#
# in in in
#
# on
#
# in
#
# on
#
# on
#
# on in
#
# in in
#
# for of
#
# in of on of
#
# of of in
#
# of of in of
#
# for in
#
# in of
#
# on in of on
#
# on of in for
#
# in
#
# for
#
# in
#
# on of
#
# in of
#
# of of
#
# for in in
#
# for of
#
# in of in of
#
# in on in in in
#
# in
#
# on on in
#
# of in in
#
# in at
#
# of of
#
# of in
#
# of of on
#
# of for on for
#
# for of for
#
# in in in
#
# for in
#
# in for in in
#
# of in
#
# in
#
# in of of on of
#
# for
#
# for in in
#
# in of of on of
#
# of in
#
# in
#
# for
#
# of in
#
# for for in of in
#
# of for
#
# of in on
#
# in of of
#
# in of in in
#
# in on
#
# in of
#
# of of in on in
#
# for of
#
# on of
#
# for of of on of
#
# of of
#
# for
#
# for for
#
# in in of for of in on
#
# on for for
#
# on on on on
#
# in in
#
# in in
#
# on
#
# of
#
# in
#
# at of
#
# on in
#
# of
#
# of
#
# of
#
# of on
#
# of
#
# of of
#
# in in
#
# of of for
#
# for
#
# of
#
# of in in
#
# of of of
#
# in
#
# in for
#
# in in on in of for
#
# of
#
# in for
#
# for of on of
#
# in on
#
# in of in of
#
# for
#
# of
#
# of of
#
# of
#
# in in in on in
#
# in on of in of of
#
# on of in in
#
# in on
#
# in
#
# in
#
# on in for
#
# at at on
#
# of in
#
# in in
#
# for on
#
# in in in
#
# in
#
# of of
#
# in on
#
# in
#
# for
#
# in in of
#
# in of in
#
# in in of in
#
# on
#
# for
#
# of in in
#
# for
#
# for in on in of of
#
# of on
#
# of in
#
# on of of
#
# in of of
#
# on of
#
# for in in
#
# of of
#
# in
#
# on of
#
# on in on
#
# on in for of in
#
# in
#
# of in on
#
# of at
#
# on of of in
#
# in
#
# on on of
#
# of on
#
# of of
#
# in
#
# of in
#
# of at
#
# for in for of
#
# on on
#
# on
#
# of
#
# of in of of
#
# on
#
# in of of
#
# in
#
# of in
#
# in
#
# on in in
#
# in of
#
# on of
#
# in in

# %% [markdown]
# **Discussion**
#
# \# todo
#
# I equate the problem of predicting prepositions to a classification problem, i.e., the five prepositions, namely on, in, of, for, and at, are regarded as five categories, and then the categories are predicted for the combination of the two words before the prepositions. This is done by putting the combination of the two words before <PREP> with each of the five prepositions into a trigram model after linear interpolation smoothing, calculating the probabilities separately, and finally outputting the preposition with the highest probability after the combination.
#
# After comparing the accuracies of different models, I found that the perplexity of the models showed a negative correlation with the accuracies in applications.
